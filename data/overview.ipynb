# %%
# CELL #1: AUTOGENERATED CELL: DO NOT ALTER THIS CELL, PROGRESS MAY BE LOST. use CELL #3 onwardsimport numpy as npfrom matplotlib import pylab as pltfrom h5_data_loaders import load, find_settingsdata = load(r"your_file_name.h5")

# %%
# CELL #2 ALTERNATIVE TO CELL #1. Only addition and commenting of lines are persistantimport h5_data_loaders as loaders

# %%
import h5_data_loaders as loaders
